# %%
import requests
import html5lib

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://news.naver.com'

# %%
html = requests.get(url).text

# %%
soup = BeautifulSoup(html, "html5lib")

# %%
tags = soup.find_all('div', "cjs_t")

# %%
for tag in tags:
    print (tag.text)
# Out:
# UAE pledges $30 billion investment in Korea after summit
# '성남FC 후원금 의혹' 이어 검찰 '위례·대장동 의혹' 이재명에 27일 소환 통보
# 험준한 지형·오래된 연식이 네팔 항공기 사고 불렀다
# "새만금 농생명용지에서 불법 전대차.. 수사해야"
# 김건희 여사 "사막여우도 많나요?" 윤 대통령 "별걸 다 알아" UAE 아크부대 격려 방문
# 김건희 여사가 또… ‘20만원짜리 국산 가방’ 들고 순방길
# 5년간 군정질문 없었던 '민주당 텃밭', 이걸 깨트린 군의원 [이상한 나라의 지방의원]
# 서울 아파트 분양가 3.3㎡ 당 3천만원 깨져
# 국내 최초 美 FDA 승인 획득, 한국 제약산업 선도한 종근당
# 황재균, 공항 라운지서 "라면은 XX"[이연호의 신조어 나들이]
# 계파갈등 수면 위로.... 하락하는 대통령 지지율
# IMF "경제 분열로 세계 GDP 7% 줄어들 것"
# 해수부, 그물에 갇힌 돌고래 3마리 바다로 돌려보내
# [르포] "10억 선 와르르"…광명 아파트값 3년 전 가격대로
# 은행 희망퇴직은 ‘돈 잔치’… 노조도 대상 확대 요구
# "조울병은 뇌의 문제… 감정 기복·우울증과 전혀 달라"
# “사무실 출근 웬 말” 카카오 노조 50% 돌파…노조원 요구 전한다
# ‘장제원 아들’ 노엘 “전두환 시대에 나 건드리면 지하실”
# '월드컵 스타' 날개 꺾었다?…박지성, 조규성 이적 거절한 이유
# 장제원 아들 노엘 "전두환 시대‥나 건드리면 바로 지하실"
# 한국 복지는 이렇게 말한다 "모멸 견뎌봐, 그럼 돈을 줄게"
# 점수도 명단도 비공개… TBS 차기대표 후보 추천도 '암흑심사'
# 에스엠 "사외이사 확대 등 지배구조 개선…얼라인 "핵심 빠진 대책"
# [만남] 거리에서 여성 노숙인 안보이는 이유 아시나요?
# 웃으며 풍경 구경하다 ‘쾅’…네팔여객기 추락 마지막 순간
# 9·19 합의 정지하면 대북확성기 켜도 돼?
# ...
